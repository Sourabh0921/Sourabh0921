# %%
import pandas
pandas.__version__
# Out:
# '1.3.5'

# %% [markdown]
# To Display Pandas's built in documentaion

# %%
import pandas as pd
pd?
import numpy as np

# %% [markdown]
# # **Creating Series from List**

# %%
data = pd.Series([0.25, 0.5, 0.75, 1.0])
data
# Out:
# 0    0.25
# 1    0.50
# 2    0.75
# 3    1.00
# dtype: float64

# %%
data.values
data.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# # Accessing element using array index

# %%
print(data[1])

data[1:3]
# Out:
# 0.5
# 1    0.50
# 2    0.75
# dtype: float64

# %% [markdown]
# # Explict Indexing

# %%
data = pd.Series([0.25, 0.5, 0.75, 1.0],
                 index=['a', 'b', 'c', 'd'])
print(data)

data['b']
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# dtype: float64
# 0.5

# %% [markdown]
# ## Series as specialized dictionary

# %%
population_dict = {'California': 38332521,
                   'Texas': 26448193,
                   'New York': 19651127,
                   'Florida': 19552860,
                   'Illinois': 12882135}
population = pd.Series(population_dict)
population
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %% [markdown]
# # Constructing Data Frame

# %%
area_dict = {'California': 423967, 'Texas': 695662, 'New York': 141297,
             'Florida': 170312, 'Illinois': 149995, 'Colorado':999999}
area = pd.Series(area_dict)
area
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# Colorado      999999
# dtype: int64

# %%
states = pd.DataFrame({'population': population,
                       'area': area})
states
# Out:
#             population    area
# California  38332521.0  423967
# Colorado           NaN  999999
# Florida     19552860.0  170312
# Illinois    12882135.0  149995
# New York    19651127.0  141297
# Texas       26448193.0  695662

# %%
print(states.index)
print(states.columns)
print(states.shape)
# Out:
# Index(['California', 'Colorado', 'Florida', 'Illinois', 'New York', 'Texas'], dtype='object')
# Index(['population', 'area'], dtype='object')
# (6, 2)

# %% [markdown]
# ## **Data Frame can be created from**
# * single series object
# * list of dicts
# * dictionary of series objects
# * two-dimensional NumPy array
# * Simple List

# %% [markdown]
# ## Creating Dataframe from Single series object

# %%
pd.DataFrame(population, columns=['population'])
# Out:
#             population
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135

# %%
population
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %% [markdown]
# ## Creating Dataframe From a list of dicts

# %%
data = [{'a': i, 'b': 2 * i} for i in range(3)]

print(data)
pd.DataFrame(data)
# Out:
# [{'a': 0, 'b': 0}, {'a': 1, 'b': 2}, {'a': 2, 'b': 4}]
#    a  b
# 0  0  0
# 1  1  2
# 2  2  4

# %% [markdown]
# ## From a dictionary of Series objects

# %%
pd.DataFrame({'population': population, 'area': area})

# %% [markdown]
# ## From a two-dimensional NumPy array

# %%
pd.DataFrame(np.random.rand(3, 2),
             columns=['col1', 'col2'],
             index=['a', 'b', 'c'])

# %% [markdown]
# ## Creating DataFrame from simple List

# %%
pd.DataFrame([1,2,3,4,5])

# %%
a = [1,2,3,4]
print(type(a))
print(type(states))

# %% [markdown]
# #Index Object

# %%
ind = pd.Index([2, 3, 5, 7, 11])
print(ind)
print(type(ind))
print(ind.shape)
# Out:
# Int64Index([2, 3, 5, 7, 11], dtype='int64')
# <class 'pandas.core.indexes.numeric.Int64Index'>
# (5,)

# %%
print(ind[1])
print(ind[::2])
print(ind.size, ind.shape, ind.ndim, ind.dtype)
# Out:
# 3
# Int64Index([2, 5, 11], dtype='int64')
# 5 (5,) 1 int64

# %% [markdown]
# **Index are immutable**

# %%
ind[1] = 0

# %% [markdown]
# **Index as ordered set**

# %%
indA = pd.Index([1, 3, 5, 7, 9])
indB = pd.Index([2, 3, 5, 7, 11])

inter = indA & indB  # intersection
print(inter)
un = indA | indB  # union
print(un)
dif = indA ^ indB  # symmetric difference
print(dif)
# Out:
# Int64Index([3, 5, 7], dtype='int64')
# Int64Index([1, 2, 3, 5, 7, 9, 11], dtype='int64')
# Int64Index([1, 2, 9, 11], dtype='int64')
